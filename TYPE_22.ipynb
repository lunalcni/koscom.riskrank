# %% [markdown]
# # TYPE_22_채권혼합형

# %% [markdown]
# ## 1. Packages

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from tqdm import trange
import unicodedata

# %% [markdown]
# ## 2. Type

# %%
fname = "TYPE_22_채권혼합형.csv"
typename = unicodedata.normalize('NFC', fname.replace(".csv", "")[8:])

# %% [markdown]
# ## 3. Import Data

# %%
df_all = pd.read_csv(fname, names=["date", "code", "nav"], usecols=[0, 1, 2], parse_dates=[0])
list_code = list(df_all["code"].unique())
print(f"Number of Funds = {len(list_code)}")
# Out:
# Number of Funds = 1788

# %% [markdown]
# ## 4. Calculate Risk

# %%
# %%time

def calc_std_y(code):
    df = df_all[df_all["code"] == code][["date", "nav"]]
    df = df.sort_values(by="date")
    df = df.set_index("date")
  
    df_1y = df.last("1Y")
    df_1y_w = df_1y.resample("W").last()

    df_3y = df.last("3Y")
    df_3y_w = df_3y.resample("W").last()
    
    df_3y_w["ret"] = df_3y_w["nav"].pct_change()
    df_3y_w = df_3y_w.iloc[1:]
    std_3y = df_3y_w["ret"].std() * np.sqrt(52)
    
    df_1y_w["ret"] = df_1y_w["nav"].pct_change()
    df_1y_w = df_1y_w.iloc[1:]
    std_1y = df_1y_w["ret"].std() * np.sqrt(52)
    
    var_3y = -np.minimum(df_3y_w["ret"].quantile(0.025), 0) * np.sqrt(52)
    
    return std_3y, std_1y, var_3y


list_std_y = []
for i in trange(len(list_code)):
    code = list_code[i]
    list_std_y.append(calc_std_y(code))
# Out:
# 100% 1788/1788 [04:58<00:00,  5.98it/s]
# CPU times: user 5min, sys: 828 ms, total: 5min 1s
# Wall time: 4min 58s

# %%
list_std_3y, list_std_1y, list_var_3y = zip(*list_std_y)

df_result = pd.DataFrame({
    "code": list_code, 
    "std_3y": list_std_3y,
    "std_1y": list_std_1y,
    "var_3y": list_var_3y,
})

bins = [0, 0.005, 0.05, 0.10, 0.15, 0.25, float("inf")]
labels = ["6등급", "5등급", "4등급", "3등급", "2등급", "1등급"]

df_result["risk_std_3y"] = pd.cut(df_result.std_3y, bins=bins, labels=labels)
df_result["risk_std_1y"] = pd.cut(df_result.std_1y, bins=bins, labels=labels)
df_result["risk_var_3y"] = pd.cut(df_result.var_3y, bins=bins, labels=labels)

df_result = df_result.dropna()

# %%
df_result
# Out:
#               code    std_3y    std_1y    var_3y risk_std_3y risk_std_1y  \
# 0     K55101AZ7044  0.103833  0.092681  0.250216         3등급         4등급
# 1     K55101B13659  0.092327  0.164754  0.191319         4등급         2등급
# 2     K55101B15233  0.091618  0.163284  0.167134         4등급         2등급
# 3     K55101B19631  0.106541  0.092638  0.249404         3등급         4등급
# 4     K55101B20308  0.064682  0.059057  0.136404         4등급         4등급
# ...            ...       ...       ...       ...         ...         ...
# 1780  KRM301972860  0.079026  0.038185  0.125283         4등급         5등급
# 1782  KRM306319737  0.128411  0.063984  0.163115         3등급         4등급
# 1783  KRM306966446  0.088042  0.046207  0.129834         4등급         5등급
# 1784  KRM306966453  0.082983  0.065888  0.148786         4등급         4등급
# 1787  KRM306966495  0.114248  0.064072  0.165229         3등급         4등급
#
#      risk_var_3y
# 0            1등급
# 1            2등급
# 2            2등급
# 3            2등급
# 4            3등급
# ...          ...
# 1780         3등급
# 1782         2등급
# 1783         3등급
# 1784         3등급
# 1787         2등급
#
# [1768 rows x 7 columns]

# %% [markdown]
# ## 5. Export Result

# %%
df_result.to_csv("RESULT_" + fname)

# %% [markdown]
# ## 6. Visualization

# %%
df_statistics_risk_std_3y = df_result["risk_std_3y"].value_counts().sort_index(ascending=False)
df_statistics_risk_std_1y = df_result["risk_std_1y"].value_counts().sort_index(ascending=False)
df_statistics_risk_var_3y = df_result["risk_var_3y"].value_counts().sort_index(ascending=False)
df_statistics = pd.concat([df_statistics_risk_std_3y, df_statistics_risk_std_1y, df_statistics_risk_var_3y], axis=1)
df_statistics = df_statistics.rename(columns={"risk_std_3y": "3년 표준편차", "risk_std_1y": "1년 표준편차", "risk_var_3y": "3년 VaR"})
df_statistics.style.background_gradient()
# Out:
# <style type="text/css">
# #T_7f784_row0_col0, #T_7f784_row0_col1, #T_7f784_row5_col0, #T_7f784_row5_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_7f784_row0_col2 {
#   background-color: #e3e0ee;
#   color: #000000;
# }
# #T_7f784_row1_col0 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_7f784_row1_col1 {
#   background-color: #fef6fa;
#   color: #000000;
# }
# #T_7f784_row1_col2, #T_7f784_row3_col0, #T_7f784_row3_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_7f784_row2_col0 {
#   background-color: #bdc8e1;
#   color: #000000;
# }
# #T_7f784_row2_col1 {
#   background-color: #f1ebf4;
#   color: #000000;
# }
# #T_7f784_row2_col2 {
#   background-color: #78abd0;
#   color: #f1f1f1;
# }
# #T_7f784_row3_col2 {
#   background-color: #c4cbe3;
#   color: #000000;
# }
# #T_7f784_row4_col0 {
#   background-color: #a4bcda;
#   color: #000000;
# }
# #T_7f784_row4_col1 {
#   background-color: #94b6d7;
#   color: #000000;
# }
# #T_7f784_row4_col2 {
#   background-color: #e4e1ef;
#   color: #000000;
# }
# #T_7f784_row5_col1 {
#   background-color: #fef6fb;
#   color: #000000;
# }
# </style>
# <table id="T_7f784">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_7f784_level0_col0" class="col_heading level0 col0" >3년 표준편차</th>
#       <th id="T_7f784_level0_col1" class="col_heading level0 col1" >1년 표준편차</th>
#       <th id="T_7f784_level0_col2" class="col_heading level0 col2" >3년 VaR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_7f784_level0_row0" class="row_heading level0 row0" >1등급</th>
#       <td id="T_7f784_row0_col0" class="data row0 col0" >3</td>
#       <td id="T_7f784_row0_col1" class="data row0 col1" >2</td>
#       <td id="T_7f784_row0_col2" class="data row0 col2" >140</td>
#     </tr>
#     <tr>
#       <th id="T_7f784_level0_row1" class="row_heading level0 row1" >2등급</th>
#       <td id="T_7f784_row1_col0" class="data row1 col0" >15</td>
#       <td id="T_7f784_row1_col1" class="data row1 col1" >14</td>
#       <td id="T_7f784_row1_col2" class="data row1 col2" >840</td>
#     </tr>
#     <tr>
#       <th id="T_7f784_level0_row2" class="row_heading level0 row2" >3등급</th>
#       <td id="T_7f784_row2_col0" class="data row2 col0" >317</td>
#       <td id="T_7f784_row2_col1" class="data row2 col1" >111</td>
#       <td id="T_7f784_row2_col2" class="data row2 col2" >412</td>
#     </tr>
#     <tr>
#       <th id="T_7f784_level0_row3" class="row_heading level0 row3" >4등급</th>
#       <td id="T_7f784_row3_col0" class="data row3 col0" >1038</td>
#       <td id="T_7f784_row3_col1" class="data row3 col1" >1149</td>
#       <td id="T_7f784_row3_col2" class="data row3 col2" >241</td>
#     </tr>
#     <tr>
#       <th id="T_7f784_level0_row4" class="row_heading level0 row4" >5등급</th>
#       <td id="T_7f784_row4_col0" class="data row4 col0" >395</td>
#       <td id="T_7f784_row4_col1" class="data row4 col1" >483</td>
#       <td id="T_7f784_row4_col2" class="data row4 col2" >135</td>
#     </tr>
#     <tr>
#       <th id="T_7f784_level0_row5" class="row_heading level0 row5" >6등급</th>
#       <td id="T_7f784_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_7f784_row5_col1" class="data row5 col1" >9</td>
#       <td id="T_7f784_row5_col2" class="data row5 col2" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
def show_values(axs, orient="v", space=.01):
    def _single(ax):
        if orient == "v":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() / 2
                _y = p.get_y() + p.get_height() + (p.get_height()*0.01)
                value = '{:d}'.format(int(p.get_height()))
                ax.text(_x, _y, value, ha="center") 
        elif orient == "h":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() + float(space)
                _y = p.get_y() + p.get_height() - (p.get_height()*0.5)
                value = '{:d}'.format(int(p.get_width()))
                ax.text(_x, _y, value, ha="left")

    if isinstance(axs, np.ndarray):
        for idx, ax in np.ndenumerate(axs):
            _single(ax)
    else:
        _single(axs)


df_statistics_long = df_statistics\
    .reset_index()\
    .melt(id_vars="index", value_vars=["3년 표준편차", "1년 표준편차", "3년 VaR"], var_name="기준")\
    .rename(columns={"index": "등급"})
axis = sns.barplot(x="등급", y="value", hue="기준", data=df_statistics_long)
axis.set_title(f"{typename} 펀드 위험등급 분포")
show_values(axis)

# %% [markdown]
# ## 8. Export Statistics

# %%
df_statistics.to_csv("STATISTICS_" + fname)
