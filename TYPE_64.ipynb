# %% [markdown]
# # TYPE_64_해외부동산형

# %% [markdown]
# ## 1. Packages

# %%
# %matplotlib inline

# %%
import numpy as np
import pandas as pd
import seaborn as sns
from tqdm import trange
import unicodedata

# %% [markdown]
# ## 2. Type

# %%
fname = "TYPE_64_해외부동산형.csv"
typename = unicodedata.normalize('NFC', fname.replace(".csv", "")[8:])

# %% [markdown]
# ## 3. Import Data

# %%
df_all = pd.read_csv(fname, names=["date", "code", "nav"], usecols=[0, 1, 2], parse_dates=[0])
list_code = list(df_all["code"].unique())
print(f"Number of Funds = {len(list_code)}")
# Out:
# Number of Funds = 433

# %% [markdown]
# ## 4. Calculate Risk

# %%
# %%time

def calc_std_y(code):
    df = df_all[df_all["code"] == code][["date", "nav"]]
    df = df.sort_values(by="date")
    df = df.set_index("date")
  
    df_1y = df.last("1Y")
    df_1y_w = df_1y.resample("W").last()

    df_3y = df.last("3Y")
    df_3y_w = df_3y.resample("W").last()
    
    df_3y_w["ret"] = df_3y_w["nav"].pct_change()
    df_3y_w = df_3y_w.iloc[1:]
    std_3y = df_3y_w["ret"].std() * np.sqrt(52)
    
    df_1y_w["ret"] = df_1y_w["nav"].pct_change()
    df_1y_w = df_1y_w.iloc[1:]
    std_1y = df_1y_w["ret"].std() * np.sqrt(52)
    
    var_3y = -np.minimum(df_3y_w["ret"].quantile(0.025), 0) * np.sqrt(52)
    
    return std_3y, std_1y, var_3y


list_std_y = []
for i in trange(len(list_code)):
    code = list_code[i]
    list_std_y.append(calc_std_y(code))
# Out:
# 100% 433/433 [00:20<00:00, 20.97it/s]
# CPU times: user 20.8 s, sys: 93.5 ms, total: 20.9 s
# Wall time: 20.7 s

# %%
list_std_3y, list_std_1y, list_var_3y = zip(*list_std_y)

df_result = pd.DataFrame({
    "code": list_code, 
    "std_3y": list_std_3y,
    "std_1y": list_std_1y,
    "var_3y": list_var_3y,
})

bins = [0, 0.005, 0.05, 0.10, 0.15, 0.25, float("inf")]
labels = ["6등급", "5등급", "4등급", "3등급", "2등급", "1등급"]

df_result["risk_std_3y"] = pd.cut(df_result.std_3y, bins=bins, labels=labels)
df_result["risk_std_1y"] = pd.cut(df_result.std_1y, bins=bins, labels=labels)
df_result["risk_var_3y"] = pd.cut(df_result.var_3y, bins=bins, labels=labels)

df_result = df_result.dropna()

# %%
df_result
# Out:
#              code    std_3y    std_1y    var_3y risk_std_3y risk_std_1y  \
# 0    K55101BU8574  0.693050  1.021024  0.246416         1등급         1등급
# 1    K55101BX3903  0.487622  1.005933  0.243237         1등급         1등급
# 2    K55101C30834  0.573651  1.033663  0.246804         1등급         1등급
# 3    K55101C30842  0.574540  1.035100  0.248116         1등급         1등급
# 4    K55101C30859  0.574087  1.034311  0.247446         1등급         1등급
# ..            ...       ...       ...       ...         ...         ...
# 428  KR5312996311  0.235805  0.191530  0.419025         2등급         2등급
# 429  KR5312996329  0.235930  0.191473  0.418907         2등급         2등급
# 430  KR5312996337  0.235749  0.191446  0.418709         2등급         2등급
# 431  KRM101664592  0.489472  0.783101  0.965185         1등급         1등급
# 432  KRM225643662  0.214397  0.027280  0.035847         2등급         5등급
#
#     risk_var_3y
# 0           2등급
# 1           2등급
# 2           2등급
# 3           2등급
# 4           2등급
# ..          ...
# 428         1등급
# 429         1등급
# 430         1등급
# 431         1등급
# 432         5등급
#
# [432 rows x 7 columns]

# %% [markdown]
# ## 5. Export Result

# %%
df_result.to_csv("RESULT_" + fname)

# %% [markdown]
# ## 6. Visualization

# %%
df_statistics_risk_std_3y = df_result["risk_std_3y"].value_counts().sort_index(ascending=False)
df_statistics_risk_std_1y = df_result["risk_std_1y"].value_counts().sort_index(ascending=False)
df_statistics_risk_var_3y = df_result["risk_var_3y"].value_counts().sort_index(ascending=False)
df_statistics = pd.concat([df_statistics_risk_std_3y, df_statistics_risk_std_1y, df_statistics_risk_var_3y], axis=1)
df_statistics = df_statistics.rename(columns={"risk_std_3y": "3년 표준편차", "risk_std_1y": "1년 표준편차", "risk_var_3y": "3년 VaR"})
df_statistics.style.background_gradient()
# Out:
# <style type="text/css">
# #T_ed7be_row0_col0 {
#   background-color: #b3c3de;
#   color: #000000;
# }
# #T_ed7be_row0_col1 {
#   background-color: #e7e3f0;
#   color: #000000;
# }
# #T_ed7be_row0_col2, #T_ed7be_row1_col0, #T_ed7be_row1_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_ed7be_row1_col2 {
#   background-color: #dddbec;
#   color: #000000;
# }
# #T_ed7be_row2_col0 {
#   background-color: #71a8ce;
#   color: #f1f1f1;
# }
# #T_ed7be_row2_col1 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_ed7be_row2_col2 {
#   background-color: #f2ecf5;
#   color: #000000;
# }
# #T_ed7be_row3_col0 {
#   background-color: #c9cee4;
#   color: #000000;
# }
# #T_ed7be_row3_col1 {
#   background-color: #d9d8ea;
#   color: #000000;
# }
# #T_ed7be_row3_col2 {
#   background-color: #fbf3f9;
#   color: #000000;
# }
# #T_ed7be_row4_col0 {
#   background-color: #fbf4f9;
#   color: #000000;
# }
# #T_ed7be_row4_col1 {
#   background-color: #f3edf5;
#   color: #000000;
# }
# #T_ed7be_row4_col2 {
#   background-color: #fdf5fa;
#   color: #000000;
# }
# #T_ed7be_row5_col0, #T_ed7be_row5_col1, #T_ed7be_row5_col2 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# </style>
# <table id="T_ed7be">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_ed7be_level0_col0" class="col_heading level0 col0" >3년 표준편차</th>
#       <th id="T_ed7be_level0_col1" class="col_heading level0 col1" >1년 표준편차</th>
#       <th id="T_ed7be_level0_col2" class="col_heading level0 col2" >3년 VaR</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_ed7be_level0_row0" class="row_heading level0 row0" >1등급</th>
#       <td id="T_ed7be_row0_col0" class="data row0 col0" >68</td>
#       <td id="T_ed7be_row0_col1" class="data row0 col1" >38</td>
#       <td id="T_ed7be_row0_col2" class="data row0 col2" >325</td>
#     </tr>
#     <tr>
#       <th id="T_ed7be_level0_row1" class="row_heading level0 row1" >2등급</th>
#       <td id="T_ed7be_row1_col0" class="data row1 col0" >202</td>
#       <td id="T_ed7be_row1_col1" class="data row1 col1" >256</td>
#       <td id="T_ed7be_row1_col2" class="data row1 col2" >63</td>
#     </tr>
#     <tr>
#       <th id="T_ed7be_level0_row2" class="row_heading level0 row2" >3등급</th>
#       <td id="T_ed7be_row2_col0" class="data row2 col0" >102</td>
#       <td id="T_ed7be_row2_col1" class="data row2 col1" >64</td>
#       <td id="T_ed7be_row2_col2" class="data row2 col2" >29</td>
#     </tr>
#     <tr>
#       <th id="T_ed7be_level0_row3" class="row_heading level0 row3" >4등급</th>
#       <td id="T_ed7be_row3_col0" class="data row3 col0" >55</td>
#       <td id="T_ed7be_row3_col1" class="data row3 col1" >54</td>
#       <td id="T_ed7be_row3_col2" class="data row3 col2" >10</td>
#     </tr>
#     <tr>
#       <th id="T_ed7be_level0_row4" class="row_heading level0 row4" >5등급</th>
#       <td id="T_ed7be_row4_col0" class="data row4 col0" >5</td>
#       <td id="T_ed7be_row4_col1" class="data row4 col1" >20</td>
#       <td id="T_ed7be_row4_col2" class="data row4 col2" >5</td>
#     </tr>
#     <tr>
#       <th id="T_ed7be_level0_row5" class="row_heading level0 row5" >6등급</th>
#       <td id="T_ed7be_row5_col0" class="data row5 col0" >0</td>
#       <td id="T_ed7be_row5_col1" class="data row5 col1" >0</td>
#       <td id="T_ed7be_row5_col2" class="data row5 col2" >0</td>
#     </tr>
#   </tbody>
# </table>

# %%
def show_values(axs, orient="v", space=.01):
    def _single(ax):
        if orient == "v":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() / 2
                _y = p.get_y() + p.get_height() + (p.get_height()*0.01)
                value = '{:d}'.format(int(p.get_height()))
                ax.text(_x, _y, value, ha="center") 
        elif orient == "h":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() + float(space)
                _y = p.get_y() + p.get_height() - (p.get_height()*0.5)
                value = '{:d}'.format(int(p.get_width()))
                ax.text(_x, _y, value, ha="left")

    if isinstance(axs, np.ndarray):
        for idx, ax in np.ndenumerate(axs):
            _single(ax)
    else:
        _single(axs)


df_statistics_long = df_statistics\
    .reset_index()\
    .melt(id_vars="index", value_vars=["3년 표준편차", "1년 표준편차", "3년 VaR"], var_name="기준")\
    .rename(columns={"index": "등급"})
axis = sns.barplot(x="등급", y="value", hue="기준", data=df_statistics_long)
axis.set_title(f"{typename} 펀드 위험등급 분포")
show_values(axis)

# %% [markdown]
# ## 8. Export Statistics

# %%
df_statistics.to_csv("STATISTICS_" + fname)
