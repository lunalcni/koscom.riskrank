# %% [markdown]
# # 펀드 위험등급 산출

# %% [markdown]
# ## 패키지 로드

# %%
# %matplotlib inline

# %%
import functools
import os
import re
from collections import defaultdict
from pathlib import Path

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
import seaborn as sns
from tqdm import trange

# %%
plt.rc('font', family='Malgun Gothic')  # For Windows

# %% [markdown]
# ## 변수 정의

# %%
TEST_PROCESS = eval(os.environ.get('TEST_PROCESS', 'True'))
VALIDATE_PROCESS = eval(os.environ.get('VALIDATE_PROCESS', 'True'))
DATA_FILEPATH = os.environ.get('DATA_FILEPATH', './data/TYPE_10_채권형.csv')
BINS = eval(os.environ.get('BINS', '[0, 0.005, 0.05, 0.10, 0.15, 0.25, float("inf")]'))

if isinstance(BINS, list):
    DICT_BINS = defaultdict(lambda: BINS)
elif isinstance(BINS, dict):
    assert all(idx_col in BINS for idx_col in ['std_1y', 'std_3y', 'var_3y'])
    DICT_BINS = BINS

print(f'{TEST_PROCESS=}, {VALIDATE_PROCESS=}, {DATA_FILEPATH=}, {BINS=}, {DICT_BINS=}')
# Out:
# TEST_PROCESS=False, VALIDATE_PROCESS=False, DATA_FILEPATH='data\\TYPE_24_부동산형.csv', BINS={'std_1y': [0, 0.005, 0.05, 0.1, 0.15, 0.25, inf], 'std_3y': [0, 0.005, 0.05, 0.1, 0.15, 0.25, inf], 'var_3y': [0, 0.005, 0.05, 0.1, 0.25, 0.35, inf]}, DICT_BINS={'std_1y': [0, 0.005, 0.05, 0.1, 0.15, 0.25, inf], 'std_3y': [0, 0.005, 0.05, 0.1, 0.15, 0.25, inf], 'var_3y': [0, 0.005, 0.05, 0.1, 0.25, 0.35, inf]}

# %% [markdown]
# ## 타입 추출

# %%
filepath = Path(DATA_FILEPATH)
filename_pattern = re.compile(r'TYPE_([0-9]+)_([^_]+)\.csv')

match_rst = re.fullmatch(filename_pattern, filepath.name)
type_no, type_name = match_rst.groups()

type_no, type_name
# Out:
# ('24', '부동산형')

# %% [markdown]
# ## 데이터 로드

# %%
lists_wo_idx_df = pd.read_csv(filepath, names=["date", "code", "nav"], usecols=[0, 1, 2], parse_dates=[0])
lists_df = lists_wo_idx_df.set_index(['code', 'date'])

codes = lists_df.index.get_level_values('code').unique()
print(f"{len(codes)=}")
# Out:
# len(codes)=58

# %% [markdown]
# ## 수치 산출 테스트
#
# 1년을 기준으로 프로세스 정의

# %% [markdown]
# ### 기간 조건 적용

# %%
if TEST_PROCESS:
    lists_1y_df = pd.concat([
        lists_df.xs(code).last('1y').assign(code=code)
        for code in codes])
    lists_1y_df.reset_index(inplace=True)
    display(lists_1y_df)

# %% [markdown]
# ### 리샘플링, 퍼센트 체인지 추출

# %%
if TEST_PROCESS:
    lists_1y_wk_df = lists_1y_df.set_index(['date']).groupby(['code'])[['nav']].resample('W').last()
    lists_1y_wk_df = lists_1y_wk_df.assign(ret=lists_1y_wk_df.groupby(['code'])[['nav']].pct_change())
    display(lists_1y_wk_df)

# %% [markdown]
# ### 표준편차 산출

# %%
if TEST_PROCESS:
    lists_1y_std_df = lists_1y_wk_df.groupby(['code'])[['ret']].std(numeric_only=True) * np.sqrt(52)
    lists_1y_std_df.reset_index(inplace=True)
    lists_1y_std_df.rename(columns={'ret': 'std_1y'}, inplace=True)
    display(lists_1y_std_df)

# %% [markdown]
# ### VaR 산출

# %%
if TEST_PROCESS:
    lists_1y_var_df = lists_1y_wk_df.groupby(['code'])[['ret']].quantile(0.025, numeric_only=True)
    lists_1y_var_df = np.minimum(lists_1y_var_df, 0) * -1 * np.sqrt(52)
    lists_1y_var_df.rename(columns={'ret': 'var_1y'}, inplace=True)
    display(lists_1y_var_df)

# %% [markdown]
# ## 수치 산출 프로세스 정의

# %%
offsets = ['1y', '3y']

# %%
# %%time

lists_rst_dfs = []

for offset in offsets:
    lists_off_df = pd.concat([
        lists_df.xs(code).last(offset).assign(code=code)
        for code in codes])
    lists_off_df.reset_index(inplace=True)

    lists_off_wk_df = lists_off_df.set_index(['date']).groupby(['code'])[['nav']].resample('W').last()
    lists_off_wk_df = lists_off_wk_df.assign(ret=lists_off_wk_df.groupby(['code'])[['nav']].pct_change())

    lists_off_std_df = lists_off_wk_df.groupby(['code'])[['ret']].std(numeric_only=True) * np.sqrt(52)
    lists_off_std_df.rename(columns={'ret': f'std_{offset}'}, inplace=True)

    lists_off_var_df = lists_off_wk_df.groupby(['code'])[['ret']].quantile(0.025, numeric_only=True)
    lists_off_var_df = np.minimum(lists_off_var_df, 0) * -1 * np.sqrt(52)
    lists_off_var_df.rename(columns={'ret': f'var_{offset}'}, inplace=True)

    lists_rst_dfs.append(lists_off_std_df)
    lists_rst_dfs.append(lists_off_var_df)

lists_rst_df = pd.concat(lists_rst_dfs, axis='columns')
lists_rst_df
# Out:
# CPU times: total: 328 ms
# Wall time: 330 ms
#                 std_1y    var_1y    std_3y    var_3y
# code
# K55203CE0163  0.451748  1.713308  0.422670  1.588136
# K55210BM8648  0.104962  0.129920  0.063965  0.012305
# K55210BM8655  0.039856  0.130372  0.035712  0.160606
# K55210BM8663  0.039856  0.130372  0.035712  0.160606
# K55223CJ6351  0.023304  0.084170  0.023304  0.084170
# K55223CJ6369  0.023308  0.085324  0.023308  0.085324
# K55223CJ6377  0.023294  0.085929  0.023294  0.085929
# K55223CJ6385  0.023309  0.084812  0.023309  0.084812
# K55223CS0338  0.010114  0.029419  0.010114  0.029419
# K55223CS0353  0.010101  0.029441  0.010101  0.029441
# K55223CS0379  0.010070  0.029519  0.010070  0.029519
# K55223CS0387  0.010115  0.029496  0.010115  0.029496
# K55223CS0395  0.010120  0.029545  0.010120  0.029545
# K55223CY2229  0.066323  0.127552  0.066323  0.127552
# K55223CY2237  0.066325  0.128231  0.066325  0.128231
# K55223CY2245  0.066315  0.127862  0.066315  0.127862
# K55301BS7495  0.079465  0.097002  0.061850  0.084846
# K55305BQ0175  0.038215  0.131235  0.036450  0.126503
# K55305BQ0183  0.037250  0.129516  0.035512  0.124782
# K55305BQ0191  0.039509  0.137223  0.037768  0.132529
# K55305C16913  0.030742  0.105703  0.028909  0.103338
# K55305C16921  0.030508  0.105815  0.028680  0.103437
# K55305C16939  0.032291  0.111952  0.030385  0.109477
# K55345BF4073  0.108736  0.110103  0.079476  0.115332
# K55345BF4099  0.074183  0.084075  0.055465  0.089702
# K55345BF4107  0.074725  0.091089  0.056422  0.097088
# K55383BM0059  0.030532  0.108251  0.030672  0.108514
# K55383BM0067  0.027031  0.093156  0.026707  0.093254
# K55383BM0075  0.028456  0.099351  0.028322  0.099523
# K55383BR0393  0.050394  0.178071  0.044841  0.200870
# K55383BR0401  0.043014  0.152063  0.038135  0.170104
# K55383BR0419  0.044903  0.158735  0.039859  0.178036
# K55383BX1997  0.906480  2.995394  0.598640  2.245763
# K55383BZ8545  0.281695  1.000379  0.214530  0.662138
# K55383C69729  0.025519  0.088319  0.024276  0.088320
# K55383C93083  0.325393  1.138316  0.262811  1.010083
# K55383CA6737  0.325634  1.140341  0.262950  1.011525
# K55383CB1042  0.007311 -0.000000  0.025871 -0.000000
# K55383CH0907  0.026132  0.080936  0.024810  0.080490
# K55383CH5534  0.023593  0.081899  0.022402  0.081448
# K55383CN5403  0.013939  0.032538  0.013939  0.032538
# K55383CP6326  0.041174  0.071303  0.041174  0.071303
# K55383CP6342  0.035702  0.063455  0.035702  0.063455
# K55383CQ2431  0.037632  0.066250  0.037632  0.066250
# K55383CQ4049  0.033697  0.060527  0.033697  0.060527
# K55383CU3706  0.001551 -0.000000  0.001551 -0.000000
# K55383CU3714  0.001387 -0.000000  0.001387 -0.000000
# K55383CU3722  0.001470 -0.000000  0.001470 -0.000000
# K55383CW4140  0.003564 -0.000000  0.003564 -0.000000
# K55383CW4157  0.003508 -0.000000  0.003508 -0.000000
# KR5102725151  0.813902  0.000834  1.211090  1.006651
# KR5102725169  0.813930  0.000694  1.211144  1.006692
# KR5102725276  0.668158  1.138214  0.982235  0.701067
# KR5107510723  0.029878  0.118446  0.029878  0.118446
# KR5308586050  0.755444  0.042515  0.584790  0.013906
# KR5309496366  0.001735  0.000076  0.001048  0.000076
# KR5309591539  0.000013 -0.000000  0.000051 -0.000000
# KRM309490337  1.449771  3.180929  1.449771  3.180929

# %% [markdown]
# ### 프로세스 테스트

# %%
# %%time

def calc_std_y(code):
    df = lists_wo_idx_df[lists_wo_idx_df['code'] == code][["date", "nav"]]
    df = df.sort_values(by="date")
    df = df.set_index("date")

    df_1y = df.last("1Y")
    df_1y_w = df_1y.resample("W").last()

    df_3y = df.last("3Y")
    df_3y_w = df_3y.resample("W").last()

    df_3y_w["ret"] = df_3y_w["nav"].pct_change()
    df_3y_w = df_3y_w.iloc[1:]
    std_3y = df_3y_w["ret"].std() * np.sqrt(52)

    df_1y_w["ret"] = df_1y_w["nav"].pct_change()
    df_1y_w = df_1y_w.iloc[1:]
    std_1y = df_1y_w["ret"].std() * np.sqrt(52)

    var_3y = -np.minimum(df_3y_w["ret"].quantile(0.025), 0) * np.sqrt(52)

    return std_3y, std_1y, var_3y

if VALIDATE_PROCESS:
    list_std_y = []
    for i in trange(len(codes)):
        code = codes[i]
        list_std_y.append(calc_std_y(code))
# Out:
# CPU times: total: 0 ns
# Wall time: 0 ns

# %%
if VALIDATE_PROCESS:
    for code_idx, code in enumerate(codes):
        for old_idx, new_name in [(0, 'std_3y'), (1, 'std_1y'), (2, 'var_3y')]:
            old_rst = list_std_y[code_idx][old_idx]
            new_rst = lists_rst_df.xs(code).xs(new_name)
            if not np.isclose(old_rst, new_rst, equal_nan=True):
                print(f"{code=}, {old_rst=}, {new_rst=}, {np.isclose(old_rst, new_rst, equal_nan=True)=}")

# %% [markdown]
# ## 등급 변환

# %%
labels = ["6등급", "5등급", "4등급", "3등급", "2등급", "1등급"]
cut_fn = functools.partial(pd.cut, labels=labels)

lists_lb_df = lists_rst_df.assign(
    risk_std_1y=cut_fn(lists_rst_df['std_1y'], bins=DICT_BINS['std_1y']),
    risk_std_3y=cut_fn(lists_rst_df['std_3y'], bins=DICT_BINS['std_3y']),
    # risk_var_1y=cut_fn(lists_rst_df['var_1y']),
    risk_var_3y=cut_fn(lists_rst_df['var_3y'], bins=DICT_BINS['var_3y']))
lists_lb_df.dropna(inplace=True)
lists_lb_df.reset_index(inplace=True)

lists_lb_df
# Out:
#             code    std_1y    var_1y    std_3y    var_3y risk_std_1y  \
# 0   K55203CE0163  0.451748  1.713308  0.422670  1.588136         1등급
# 1   K55210BM8648  0.104962  0.129920  0.063965  0.012305         3등급
# 2   K55210BM8655  0.039856  0.130372  0.035712  0.160606         5등급
# 3   K55210BM8663  0.039856  0.130372  0.035712  0.160606         5등급
# 4   K55223CJ6351  0.023304  0.084170  0.023304  0.084170         5등급
# 5   K55223CJ6369  0.023308  0.085324  0.023308  0.085324         5등급
# 6   K55223CJ6377  0.023294  0.085929  0.023294  0.085929         5등급
# 7   K55223CJ6385  0.023309  0.084812  0.023309  0.084812         5등급
# 8   K55223CS0338  0.010114  0.029419  0.010114  0.029419         5등급
# 9   K55223CS0353  0.010101  0.029441  0.010101  0.029441         5등급
# 10  K55223CS0379  0.010070  0.029519  0.010070  0.029519         5등급
# 11  K55223CS0387  0.010115  0.029496  0.010115  0.029496         5등급
# 12  K55223CS0395  0.010120  0.029545  0.010120  0.029545         5등급
# 13  K55223CY2229  0.066323  0.127552  0.066323  0.127552         4등급
# 14  K55223CY2237  0.066325  0.128231  0.066325  0.128231         4등급
# 15  K55223CY2245  0.066315  0.127862  0.066315  0.127862         4등급
# 16  K55301BS7495  0.079465  0.097002  0.061850  0.084846         4등급
# 17  K55305BQ0175  0.038215  0.131235  0.036450  0.126503         5등급
# 18  K55305BQ0183  0.037250  0.129516  0.035512  0.124782         5등급
# 19  K55305BQ0191  0.039509  0.137223  0.037768  0.132529         5등급
# 20  K55305C16913  0.030742  0.105703  0.028909  0.103338         5등급
# 21  K55305C16921  0.030508  0.105815  0.028680  0.103437         5등급
# 22  K55305C16939  0.032291  0.111952  0.030385  0.109477         5등급
# 23  K55345BF4073  0.108736  0.110103  0.079476  0.115332         3등급
# 24  K55345BF4099  0.074183  0.084075  0.055465  0.089702         4등급
# 25  K55345BF4107  0.074725  0.091089  0.056422  0.097088         4등급
# 26  K55383BM0059  0.030532  0.108251  0.030672  0.108514         5등급
# 27  K55383BM0067  0.027031  0.093156  0.026707  0.093254         5등급
# 28  K55383BM0075  0.028456  0.099351  0.028322  0.099523         5등급
# 29  K55383BR0393  0.050394  0.178071  0.044841  0.200870         4등급
# 30  K55383BR0401  0.043014  0.152063  0.038135  0.170104         5등급
# 31  K55383BR0419  0.044903  0.158735  0.039859  0.178036         5등급
# 32  K55383BX1997  0.906480  2.995394  0.598640  2.245763         1등급
# 33  K55383BZ8545  0.281695  1.000379  0.214530  0.662138         1등급
# 34  K55383C69729  0.025519  0.088319  0.024276  0.088320         5등급
# 35  K55383C93083  0.325393  1.138316  0.262811  1.010083         1등급
# 36  K55383CA6737  0.325634  1.140341  0.262950  1.011525         1등급
# 37  K55383CH0907  0.026132  0.080936  0.024810  0.080490         5등급
# 38  K55383CH5534  0.023593  0.081899  0.022402  0.081448         5등급
# 39  K55383CN5403  0.013939  0.032538  0.013939  0.032538         5등급
# 40  K55383CP6326  0.041174  0.071303  0.041174  0.071303         5등급
# 41  K55383CP6342  0.035702  0.063455  0.035702  0.063455         5등급
# 42  K55383CQ2431  0.037632  0.066250  0.037632  0.066250         5등급
# 43  K55383CQ4049  0.033697  0.060527  0.033697  0.060527         5등급
# 44  KR5102725151  0.813902  0.000834  1.211090  1.006651         1등급
# 45  KR5102725169  0.813930  0.000694  1.211144  1.006692         1등급
# 46  KR5102725276  0.668158  1.138214  0.982235  0.701067         1등급
# 47  KR5107510723  0.029878  0.118446  0.029878  0.118446         5등급
# 48  KR5308586050  0.755444  0.042515  0.584790  0.013906         1등급
# 49  KR5309496366  0.001735  0.000076  0.001048  0.000076         6등급
# 50  KRM309490337  1.449771  3.180929  1.449771  3.180929         1등급
#
#    risk_std_3y risk_var_3y
# 0          1등급         1등급
# 1          4등급         5등급
# 2          5등급         3등급
# 3          5등급         3등급
# 4          5등급         4등급
# 5          5등급         4등급
# 6          5등급         4등급
# 7          5등급         4등급
# 8          5등급         5등급
# 9          5등급         5등급
# 10         5등급         5등급
# 11         5등급         5등급
# 12         5등급         5등급
# 13         4등급         3등급
# 14         4등급         3등급
# 15         4등급         3등급
# 16         4등급         4등급
# 17         5등급         3등급
# 18         5등급         3등급
# 19         5등급         3등급
# 20         5등급         3등급
# 21         5등급         3등급
# 22         5등급         3등급
# 23         4등급         3등급
# 24         4등급         4등급
# 25         4등급         4등급
# 26         5등급         3등급
# 27         5등급         4등급
# 28         5등급         4등급
# 29         5등급         3등급
# 30         5등급         3등급
# 31         5등급         3등급
# 32         1등급         1등급
# 33         2등급         1등급
# 34         5등급         4등급
# 35         1등급         1등급
# 36         1등급         1등급
# 37         5등급         4등급
# 38         5등급         4등급
# 39         5등급         5등급
# 40         5등급         4등급
# 41         5등급         4등급
# 42         5등급         4등급
# 43         5등급         4등급
# 44         1등급         1등급
# 45         1등급         1등급
# 46         1등급         1등급
# 47         5등급         3등급
# 48         1등급         5등급
# 49         6등급         6등급
# 50         1등급         1등급

# %% [markdown]
# #### 프로세스 테스트

# %%
if VALIDATE_PROCESS:
    list_std_3y, list_std_1y, list_var_3y = zip(*list_std_y)

    df_result = pd.DataFrame({
        "code": codes,
        "std_3y": list_std_3y,
        "std_1y": list_std_1y,
        "var_3y": list_var_3y,
    })

    bins = [0, 0.005, 0.05, 0.10, 0.15, 0.25, float("inf")]
    labels = ["6등급", "5등급", "4등급", "3등급", "2등급", "1등급"]

    df_result["risk_std_3y"] = pd.cut(df_result.std_3y, bins=bins, labels=labels)
    df_result["risk_std_1y"] = pd.cut(df_result.std_1y, bins=bins, labels=labels)
    df_result["risk_var_3y"] = pd.cut(df_result.var_3y, bins=bins, labels=labels)

    df_result = df_result.dropna()

# %%
if VALIDATE_PROCESS:
    display(
        (lists_lb_df[['code', 'risk_std_1y', 'risk_std_3y', 'risk_var_3y']].set_index(['code'])
        == df_result[['code', 'risk_std_1y', 'risk_std_3y', 'risk_var_3y']].set_index(['code'])).all())

# %% [markdown]
# ## 등급 결과 출력

# %%
os.makedirs('results', exist_ok=True)
lists_lb_df.to_excel(f'results/RESULT_{type_no}_{type_name}.xlsx', index=False)

# %% [markdown]
# ## 시각화

# %%
risk_std_3y_stat_df = lists_lb_df["risk_std_3y"].value_counts().sort_index(ascending=False)
risk_std_1y_stat_df = lists_lb_df["risk_std_1y"].value_counts().sort_index(ascending=False)
risk_var_3y_stat_df = lists_lb_df["risk_var_3y"].value_counts().sort_index(ascending=False)
stat_df = pd.concat([risk_std_3y_stat_df, risk_std_1y_stat_df, risk_var_3y_stat_df], axis=1)
stat_df = stat_df.rename(columns={"risk_std_3y": "3년 표준편차", "risk_std_1y": "1년 표준편차", "risk_var_3y": "3년 VaR"})
stat_df.reset_index(names=['등급'], inplace=True)

stat_df.set_index('등급').style.background_gradient()
# Out:
# <style type="text/css">
# #T_2fe5e_row0_col0 {
#   background-color: #c5cce3;
#   color: #000000;
# }
# #T_2fe5e_row0_col1 {
#   background-color: #b8c6e0;
#   color: #000000;
# }
# #T_2fe5e_row0_col2 {
#   background-color: #65a3cb;
#   color: #f1f1f1;
# }
# #T_2fe5e_row1_col0, #T_2fe5e_row5_col0, #T_2fe5e_row5_col1 {
#   background-color: #faf3f9;
#   color: #000000;
# }
# #T_2fe5e_row1_col1, #T_2fe5e_row1_col2, #T_2fe5e_row2_col0 {
#   background-color: #fff7fb;
#   color: #000000;
# }
# #T_2fe5e_row2_col1 {
#   background-color: #f5eff6;
#   color: #000000;
# }
# #T_2fe5e_row2_col2, #T_2fe5e_row4_col0, #T_2fe5e_row4_col1 {
#   background-color: #023858;
#   color: #f1f1f1;
# }
# #T_2fe5e_row3_col0 {
#   background-color: #d0d1e6;
#   color: #000000;
# }
# #T_2fe5e_row3_col1 {
#   background-color: #d6d6e9;
#   color: #000000;
# }
# #T_2fe5e_row3_col2 {
#   background-color: #034871;
#   color: #f1f1f1;
# }
# #T_2fe5e_row4_col2 {
#   background-color: #80aed2;
#   color: #f1f1f1;
# }
# #T_2fe5e_row5_col2 {
#   background-color: #f6eff7;
#   color: #000000;
# }
# </style>
# <table id="T_2fe5e">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_2fe5e_level0_col0" class="col_heading level0 col0" >3년 표준편차</th>
#       <th id="T_2fe5e_level0_col1" class="col_heading level0 col1" >1년 표준편차</th>
#       <th id="T_2fe5e_level0_col2" class="col_heading level0 col2" >3년 VaR</th>
#     </tr>
#     <tr>
#       <th class="index_name level0" >등급</th>
#       <th class="blank col0" >&nbsp;</th>
#       <th class="blank col1" >&nbsp;</th>
#       <th class="blank col2" >&nbsp;</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_2fe5e_level0_row0" class="row_heading level0 row0" >1등급</th>
#       <td id="T_2fe5e_row0_col0" class="data row0 col0" >9</td>
#       <td id="T_2fe5e_row0_col1" class="data row0 col1" >10</td>
#       <td id="T_2fe5e_row0_col2" class="data row0 col2" >9</td>
#     </tr>
#     <tr>
#       <th id="T_2fe5e_level0_row1" class="row_heading level0 row1" >2등급</th>
#       <td id="T_2fe5e_row1_col0" class="data row1 col0" >1</td>
#       <td id="T_2fe5e_row1_col1" class="data row1 col1" >0</td>
#       <td id="T_2fe5e_row1_col2" class="data row1 col2" >0</td>
#     </tr>
#     <tr>
#       <th id="T_2fe5e_level0_row2" class="row_heading level0 row2" >3등급</th>
#       <td id="T_2fe5e_row2_col0" class="data row2 col0" >0</td>
#       <td id="T_2fe5e_row2_col1" class="data row2 col1" >2</td>
#       <td id="T_2fe5e_row2_col2" class="data row2 col2" >17</td>
#     </tr>
#     <tr>
#       <th id="T_2fe5e_level0_row3" class="row_heading level0 row3" >4등급</th>
#       <td id="T_2fe5e_row3_col0" class="data row3 col0" >8</td>
#       <td id="T_2fe5e_row3_col1" class="data row3 col1" >7</td>
#       <td id="T_2fe5e_row3_col2" class="data row3 col2" >16</td>
#     </tr>
#     <tr>
#       <th id="T_2fe5e_level0_row4" class="row_heading level0 row4" >5등급</th>
#       <td id="T_2fe5e_row4_col0" class="data row4 col0" >32</td>
#       <td id="T_2fe5e_row4_col1" class="data row4 col1" >31</td>
#       <td id="T_2fe5e_row4_col2" class="data row4 col2" >8</td>
#     </tr>
#     <tr>
#       <th id="T_2fe5e_level0_row5" class="row_heading level0 row5" >6등급</th>
#       <td id="T_2fe5e_row5_col0" class="data row5 col0" >1</td>
#       <td id="T_2fe5e_row5_col1" class="data row5 col1" >1</td>
#       <td id="T_2fe5e_row5_col2" class="data row5 col2" >1</td>
#     </tr>
#   </tbody>
# </table>

# %%
def show_values(axs, orient="v", space=.01):
    def _single(ax):
        if orient == "v":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() / 2
                _y = p.get_y() + p.get_height() + (p.get_height() * 0.01)
                value = '{:d}'.format(int(p.get_height()))
                ax.text(_x, _y, value, ha="center")
        elif orient == "h":
            for p in ax.patches:
                _x = p.get_x() + p.get_width() + float(space)
                _y = p.get_y() + p.get_height() - (p.get_height() * 0.5)
                value = '{:d}'.format(int(p.get_width()))
                ax.text(_x, _y, value, ha="left")

    if isinstance(axs, np.ndarray):
        for idx, ax in np.ndenumerate(axs):
            _single(ax)
    else:
        _single(axs)


stat_df_long = (
    stat_df
    .melt(id_vars="등급", value_vars=["3년 표준편차", "1년 표준편차", "3년 VaR"], var_name="기준") \
    .rename(columns={"index": "등급"})
)
axis = sns.barplot(x="등급", y="value", hue="기준", data=stat_df_long)
axis.set_title(f"{type_name} 펀드 위험등급 분포")
show_values(axis)

# %% [markdown]
# ## 통계 결과 출력

# %%
os.makedirs('results', exist_ok=True)
stat_df.to_excel(f'results/STATISTICS_{type_no}_{type_name}.xlsx', index=False)
